# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fname_fmt_ = "/home/antonio/Tesis/Datasets_compressed/0/days/{}0_{:05d}.npz"
fname_lon = "/home/antonio/Tesis/Datasets_compressed/0/days/lon.txt"
fname_lat = "/home/antonio/Tesis/Datasets_compressed/0/days/lat.txt"

# %%
U = np.load(fname_fmt_.format("U",110))["uv"]
lon = np.loadtxt(fname_lon)
lat = np.loadtxt(fname_lat)
plt.figure()
plt.pcolor(lon,lat,U)
plt.show()

# %%
plt.pcolor(U)

# %%
fname_fmt2_ = "/home/antonio/Tesis/Datasets/787/days/{}0_{:05d}.txt"

# %%
U2 = np.loadtxt(fname_fmt2_.format("U",110))
plt.pcolor(U2)
